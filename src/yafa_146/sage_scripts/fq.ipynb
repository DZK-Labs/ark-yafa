# %%
q = 34780846793597649115902360759330114765953831037762036596538890219938834838634659810167270279641323601509886108333904651602464968545001642013075102043510458751533543897428201

# %%
(q - 1) / 2 % 2
# Out:
# 0

# %%
factor(q - 1)
# Out:
# 2^3 * 3 * 5^2 * 11 * 5269825271757219563015509205959108297871792581479096454021043972718005278581009062146556102975958121440891834596046159333706813415909339698950773036895524053262658166277

# %%
for i in range(1, 1000):
    gen = Integer(i)
    if pow(gen, (q - 1) / 2, q) == 1:
        continue
    if pow(gen, (q - 1) / 3, q) == 1:
        continue
    if pow(gen, (q - 1) / 5, q) == 1:
        continue
    if pow(gen, (q - 1) / 11, q) == 1:
        continue
    if pow(gen, (q - 1) / 5269825271757219563015509205959108297871792581479096454021043972718005278581009062146556102975958121440891834596046159333706813415909339698950773036895524053262658166277, q) == 1:
        continue
    print(gen)
    print(pow(gen, (q - 1) / 2, q))
    print(pow(gen, (q - 1) / 3, q))
    print(pow(gen, (q - 1) / 5, q))
    print(pow(gen, (q - 1) / 11, q))
    print(pow(gen, (q - 1) / 5269825271757219563015509205959108297871792581479096454021043972718005278581009062146556102975958121440891834596046159333706813415909339698950773036895524053262658166277, q))
    break
# Out:
# 59
# 34780846793597649115902360759330114765953831037762036596538890219938834838634659810167270279641323601509886108333904651602464968545001642013075102043510458751533543897428200
# 22684684505229882416948285270218997440839683235327132785256469607245693680604029123404282437563474551944295516999841064542480240558845597162904726440521080541363789749413059
# 20715091683655972694840823802324879512783509698092509003807829688333753759756423274477270160335393492478931941624301067389678059773225233200949168872257512113472298214715149
# 4223680706092063669460633142401529154029882468152019268616798045554296903468485216185846077018774176560437209329159082294111793469767604549641284909619930134615296945447666
# 105337446502333084845270782098500315734925010969266018020951891106226200203043096590938936925210957942939756623611235434240840237605131883819485731464877629643492354004081
